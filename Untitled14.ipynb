# %% [markdown]
# <a href="https://colab.research.google.com/github/Arthur6363/Data-Science-ML/blob/main/Untitled14.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

# %%
iris = load_iris()
x = iris.data
y = iris.target

# %%
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=63)

# %%
knn = KNeighborsClassifier(n_neighbors=5)
model = knn.fit(x_train, y_train)
model.score(x_test,y_test)
# Out:
# 0.9

# %%
y_pred = knn.predict(x_test)

# %%
accuray = accuracy_score(y_test,y_pred)
print("Test verileri üzerinde doğruluk skoru:", accuray)
# Out:
# Test verileri üzerinde doğruluk skoru: 0.9

# %%
from sklearn.metrics import confusion_matrix

# %%
cm = confusion_matrix(y_test, y_pred)
print("Karmaşıklık Matrisi:")
print(cm)
# Out:
# Karmaşıklık Matrisi:
# [[ 6  0  0]
#  [ 0 10  2]
#  [ 0  1 11]]

# %%
from sklearn.svm import SVC
svc = SVC(kernel = "linear")
model = svc.fit(x_train, y_train)
model.score(x_test, y_test)
# Out:
# 0.9666666666666667

# %%
y_pred = model.predict(x_test)

# %%
accuray = accuracy_score(y_test, y_pred)
print(accuray)
# Out:
# 0.9666666666666667

# %%
cm = confusion_matrix(y_test, y_pred)
print("Karmaşıklık Matrisi:")
print(cm)
# Out:
# Karmaşıklık Matrisi:
# [[ 6  0  0]
#  [ 0 11  1]
#  [ 0  0 12]]

# %%
import matplotlib.pyplot as plt

fig, axes = plt.subplots(1, 2, figsize=(9, 4))

axes[0].scatter(x_test[:, 0], x_test[:, 2], c=y_test, cmap='viridis')
axes[0].set_xlabel('Sepal Length', fontsize=15)
axes[0].set_ylabel('Petal Length', fontsize=15)
axes[0].set_title('Test Data', fontsize=15)

axes[1].scatter(x_test[:, 0], x_test[:, 2], c=y_pred, cmap='viridis')
axes[1].set_xlabel('Sepal Length', fontsize=15)
axes[1].set_ylabel('Petal Length', fontsize=15)
axes[1].set_title('Predicted Data', fontsize=15)

plt.show()

# %%
class_labels = iris.target_names

# Gerçek ve tahmin edilen sınıfların dağılımını gösteren grafik
plt.figure(figsize=(9, 4))

plt.subplot(1, 2, 1)
plt.hist([y_test, y_pred], bins=3, color=['skyblue', 'salmon'], label=['Gerçek Sınıflar', 'Tahmin Edilen Sınıflar'])
plt.xticks(range(3), class_labels)
plt.xlabel('Sınıflar')
plt.ylabel('Örnek Sayısı')
plt.title('Gerçek ve Tahmin Edilen Sınıfların Dağılımı')
plt.legend()

# Gerçek ve tahmin edilen sınıfları karşılaştıran grafik
plt.subplot(1, 2, 2)
plt.scatter(range(len(y_test)), y_test, color='skyblue', label='Gerçek Sınıflar', marker='o')
plt.scatter(range(len(y_pred)), y_pred, color='salmon', label='Tahmin Edilen Sınıflar', marker='x')
plt.xlabel('Örnekler')
plt.ylabel('Sınıflar')
plt.title('Gerçek ve Tahmin Edilen Sınıfların Karşılaştırılması')
plt.legend()

plt.show()
