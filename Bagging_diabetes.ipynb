# %% [markdown]
# <a href="https://colab.research.google.com/github/Arthur6363/Data-Science-ML/blob/main/Bagging_diabetes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv("pima-indians-diabetes.csv")
df.head()
# Out:
#    6  148  72  35    0  33.6  0.627  50  1
# 0  1   85  66  29    0  26.6  0.351  31  0
# 1  8  183  64   0    0  23.3  0.672  32  1
# 2  1   89  66  23   94  28.1  0.167  21  0
# 3  0  137  40  35  168  43.1  2.288  33  1
# 4  5  116  74   0    0  25.6  0.201  30  0

# %%
df.columns=["Pregnancies","Glucose","Bloodpressure","SkinThickness","Insulin", "BMI","DiabetesPedigreeFunction","Age","Outcome" ]

# %%
df.head()
# Out:
#    Pregnancies  Glucose  Bloodpressure  SkinThickness  Insulin   BMI  \
# 0            1       85             66             29        0  26.6
# 1            8      183             64              0        0  23.3
# 2            1       89             66             23       94  28.1
# 3            0      137             40             35      168  43.1
# 4            5      116             74              0        0  25.6
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.351   31        0
# 1                     0.672   32        1
# 2                     0.167   21        0
# 3                     2.288   33        1
# 4                     0.201   30        0

# %%
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# Bloodpressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
df.describe().transpose()
# Out:
#                           count        mean         std     min      25%  \
# Pregnancies               767.0    3.842243    3.370877   0.000   1.0000
# Glucose                   767.0  120.859192   31.978468   0.000  99.0000
# Bloodpressure             767.0   69.101695   19.368155   0.000  62.0000
# SkinThickness             767.0   20.517601   15.954059   0.000   0.0000
# Insulin                   767.0   79.903520  115.283105   0.000   0.0000
# BMI                       767.0   31.990482    7.889091   0.000  27.3000
# DiabetesPedigreeFunction  767.0    0.471674    0.331497   0.078   0.2435
# Age                       767.0   33.219035   11.752296  21.000  24.0000
# Outcome                   767.0    0.348110    0.476682   0.000   0.0000
#
#                               50%      75%     max
# Pregnancies                 3.000    6.000   17.00
# Glucose                   117.000  140.000  199.00
# Bloodpressure              72.000   80.000  122.00
# ...

# %%
df.head(3)
# Out:
#    Pregnancies  Glucose  Bloodpressure  SkinThickness  Insulin   BMI  \
# 0            1       85             66             29        0  26.6
# 1            8      183             64              0        0  23.3
# 2            1       89             66             23       94  28.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.351   31        0
# 1                     0.672   32        1
# 2                     0.167   21        0

# %%
df["Outcome"].value_counts()
# Out:
# 0    500
# 1    267
# Name: Outcome, dtype: int64

# %%
x = df.drop(["Outcome"], axis=1)
y= df["Outcome"]

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x_scaled = scaler.fit_transform(x)
x_scaled[:3]
# Out:
# array([[-0.84372629, -1.12208597, -0.16024856,  0.53202348, -0.69355921,
#         -0.68372895, -0.36426474, -0.18894038],
#        [ 1.23423997,  1.94447577, -0.26357823, -1.28688187, -0.69355921,
#         -1.10230105,  0.60470064, -0.1037951 ],
#        [-0.84372629, -0.99692019, -0.16024856,  0.15569823,  0.12235685,
#         -0.49346891, -0.91968415, -1.0403932 ]])

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x_scaled, y, stratify=y, random_state=10)

# %%
x_train.shape
# Out:
# (575, 8)

# %%
x_test.shape
# Out:
# (192, 8)

# %%
y_train.value_counts()
# Out:
# 0    375
# 1    200
# Name: Outcome, dtype: int64

# %%
y_test.value_counts()
# Out:
# 0    125
# 1     67
# Name: Outcome, dtype: int64

# %%
from sklearn.model_selection import cross_val_score
from sklearn.tree import DecisionTreeClassifier
scores = cross_val_score(DecisionTreeClassifier(), x, y, cv=5)
scores
# Out:
# array([0.70779221, 0.64935065, 0.70588235, 0.75163399, 0.73856209])

# %%
scores.mean()
# Out:
# 0.7106442577030813

# %%
from sklearn.ensemble import BaggingClassifier
bag_model = BaggingClassifier(base_estimator=DecisionTreeClassifier(),
    n_estimators=100,
    max_samples=0.8,
    oob_score=True,
    random_state=0)
bag_model.fit(x_train, y_train)
bag_model.oob_score_
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# 0.7634782608695653

# %%
bag_model.score(x_test, y_test)
# Out:
# 0.7552083333333334

# %%
from sklearn.ensemble import RandomForestClassifier

scores = cross_val_score(RandomForestClassifier(n_estimators=50), x, y, cv=5)
scores.mean()
# Out:
# 0.7640522875816993
